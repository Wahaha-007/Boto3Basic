# %% [markdown]
# # Athena CLI : Table

# %% [markdown]
# ### 1. List Table

# %%
# !aws athena list-table-metadata \
--catalog-name AwsDataCatalog\
--database-name myretail
# Out:
# {
#     "TableMetadataList": [
#         {
#             "Name": "order_items",
#             "CreateTime": "2024-02-18T01:27:00+07:00",
#             "TableType": "EXTERNAL_TABLE",
#             "Columns": [
#                 {
#                     "Name": "order_item_id",
#                     "Type": "int"
#                 },
#                 {
#                     "Name": "order_item_order_id",
#                     "Type": "int"
#                 },
#                 {
#                     "Name": "order_item_product_id",
#                     "Type": "int"
#                 },
#                 {
#                     "Name": "order_item_quantity",
#                     "Type": "int"
#                 },
#                 {
#                     "Name": "order_item_subtotal",
#                     "Type": "double"
#                 },
#                 {
#                     "Name": "order_item_product_price",
#                     "Type": "double"
#                 }
# ...
